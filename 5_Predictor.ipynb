# %% [markdown]
# # 1.Prediction

# %%
# 直接从模块导入predict_avp函数
from Model_training_and_testing.Prediction_GAT import predict_avp

# 使用预测函数
try:
    results, files = predict_avp(
        input_data="1_Data/Processed_data_set/Final_merged_data_set/TS.csv",
        batch_size=256,
        create_visualization=True
    )
    print(f"预测完成! 结果文件: {files}")

except Exception as e:
    print(f"预测失败: {e}")
# Out:
# 🚀 Initializing End-to-End AVP Predictor...
# 🖥️ Using device: cuda
# 🤖 Loading GAT models from: 4_Results_TR_RS/GAT_Comparison_4.0A/3Layer_GAT
# ✅ Successfully loaded 5 models for ensemble prediction.
# ✅ Predictor initialized successfully!
#
# 🚀 Starting End-to-End AVP Prediction...
#
# 🔄 Step 1: Data Processing & Graph Building
# ✅ Input data standardized to: 5_Results_Predicted/TS/input_for_prediction.csv
# 🔧 Building molecular graphs...
# ✅ Found and using existing graph file: 3_Graph_Data/TS/TS_ESMC_4.0A.pkl
#
# 🔄 Step 2: Model Prediction
# 🔮 Making predictions...
#
# 🔄 Step 3: Results Processing
# 💾 Saving prediction results...
# 📄 Full results saved to: 5_Results_Predicted/TS/predictions_full.csv
# 📋 Simple results saved to: 5_Results_Predicted/TS/predictions_simple.csv
#
# 📊 Prediction Summary
# ============================================================
# Total sequences predicted: 9297
#   - AVP: 2328 (25.0%)
#   - non-AVP: 6969 (75.0%)
#
# 🔥 Top 5 AVP Predictions:
#          Id  AVP_Probability
# DRAVPe00237              1.0
# DRAVPe00580              1.0
#      HIP895              1.0
#      HIP883              1.0
# DRAVPe00581              1.0
#
# 🔄 Step 4: Creating Visualization
# 📊 Creating visualization...
# 📈 Visualization saved to: 5_Results_Predicted/TS/prediction_analysis.png
#
# 🎉 End-to-end prediction completed successfully!
# 预测完成! 结果文件: {'full_results': '5_Results_Predicted/TS/predictions_full.csv', 'simple_results': '5_Results_Predicted/TS/predictions_simple.csv'}
