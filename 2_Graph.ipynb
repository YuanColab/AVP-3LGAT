# %%
import pandas as pd
import os
from collections import Counter
from Feature_extraction.graph_builder import build_graphs_from_files

# ========== Adjustable Parameters ==========
INPUT_FILE = "1_Data/Processed_data_set/Final_merged_data_set/TS.csv"
USE_ESMC = False
USE_AAINDEX = True
DISTANCE_THRESHOLD = 4.0
FORCE_REPROCESS = False
VALIDATE_OUTPUT = True

# ========== Processing Pipeline ==========
print("🔬 Processing External Dataset")

if not os.path.exists(INPUT_FILE):
    print(f"❌ File not found: {INPUT_FILE}")
else:
    print(f"✅ File exists: {INPUT_FILE}")
    
    try:
        # Load data
        df = pd.read_csv(INPUT_FILE)
        base_filename = os.path.splitext(os.path.basename(INPUT_FILE))[0]
        
        print(f"📊 Data rows: {len(df)}, columns: {len(df.columns)}")
        
        # Check labels and sequences
        if 'Label' in df.columns:
            label_dist = Counter(df['Label'])
            print(f"🏷️  Label distribution: {dict(label_dist)}")
        
        if 'Sequence' in df.columns:
            seq_lengths = df['Sequence'].str.len()
            print(f"📏 Sequence lengths: {seq_lengths.min()}-{seq_lengths.max()}, average: {seq_lengths.mean():.1f}")
        
        # Configuration parameters
        config = {
            'graph': {
                'use_esmc': USE_ESMC,
                'use_aaindex': USE_AAINDEX,
                'distance_threshold': DISTANCE_THRESHOLD
            },
            'data': {
                'output_base_dir': '3_Graph_Data',  
            }
        }
        
        print(f"⚙️  Configuration: ESMC={USE_ESMC}, AAIndex={USE_AAINDEX}, distance={DISTANCE_THRESHOLD}Å")
        
        # Build graph dataset
        print("🚀 Starting graph dataset construction...")
        graphs_iamp, stats_iamp = build_graphs_from_files(
            file_configs=[(INPUT_FILE, None)],
            output_name=base_filename,
            config=config,
            force_reprocess=FORCE_REPROCESS,
            validate_output=VALIDATE_OUTPUT
        )
        
        # Display results
        if stats_iamp:
            success_rate = (stats_iamp.get('successful_graphs', 0) / stats_iamp.get('total_sequences', 1)) * 100
            print(f"📊 Total sequences: {stats_iamp.get('total_sequences', 0)}, successful: {stats_iamp.get('successful_graphs', 0)}, success rate: {success_rate:.1f}%")
        
        if graphs_iamp:
            # Label distribution
            labels = [graph.y.item() for graph in graphs_iamp]
            label_counts = Counter(labels)
            print(f"🎯 Graph label distribution: {dict(label_counts)}")
            
            # Save path
            feature_suffix = ""
            if USE_ESMC:
                feature_suffix += "ESMC"
            if USE_AAINDEX:
                if feature_suffix:
                    feature_suffix += "+"
                feature_suffix += "AAIndex"
            
            filename = f"3_Graph_Data/{base_filename}/{base_filename}_{feature_suffix}_{DISTANCE_THRESHOLD}A.pkl"
            print(f"💾 Saved to: {filename}")
        
        print("✅ Processing completed!")
        
    except Exception as e:
        print(f"❌ Processing failed: {e}")
# Out:
# 🔬 Processing External Dataset
# ✅ File exists: 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 📊 Data rows: 9297, columns: 7
# 🏷️  Label distribution: {0: 7894, 1: 1403}
# 📏 Sequence lengths: 5-50, average: 29.6
# ⚙️  Configuration: ESMC=False, AAIndex=True, distance=4.0Å
# 🚀 Starting graph dataset construction...
# Graph builder initialized (strict mode - CSV input only)
# Using features: ESMC=False, AAIndex=True
# Distance threshold: 4.0Å
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.utils:setup_dataset_logging:66 - Dataset-specific logging initialized: 2_Log/2.2_Feature_extraction/TS/TS_AAIndex_4.0A.log
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:764 - ================================================================================
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:765 - Automated CSV Graph Construction Pipeline (Strict Mode)
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:766 - ================================================================================
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:767 - Log file: 2_Log/2.2_Feature_extraction/TS/TS_AAIndex_4.0A.log
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:768 - Input CSV: 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:771 - Step 1: Loading and validating CSV data
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:772 - ============================================================
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:204 - Loaded 9297 sequences from 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:208 - Sequence length range: 5-50, average: 29.6
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:212 - Label distribution: {0: 7894, 1: 1403}
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:780 - Output directory: 3_Graph_Data/TS
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:790 - Feature configuration: AAIndex
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:791 - Distance threshold: 4.0Å
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:794 - Step 2: Extracting features
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:automated_pipeline:795 - ============================================================
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.graph_builder:extract_features_if_needed:250 - Extracting ESMFold structures...
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.utils:get_device:116 - CUDA available: NVIDIA GeForce RTX 3070 Laptop GPU
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:__init__:32 - ESMFold Processor initialized with device: cuda, batch size: 5
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:process_dataset:143 - Starting ESMFold structure prediction: 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:process_dataset:155 - Dataset size: 9297 sequences
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:process_dataset:156 - Output directory: 3_Graph_Data/TS/esmfold_structures
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:process_dataset:165 - Found 9297 existing PDB files, will skip
# 2025-06-27 15:46:56 | INFO     | Feature_extraction.esmfold:process_dataset:168 - All PDB files exist, skipping processing
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:extract_features_if_needed:267 - Extracting AAIndex features...
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:__init__:68 - AAIndex Processor initialized with file: Feature_extraction/aaindex1.csv
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:__init__:69 - Default output directory: 3_Graph_Data
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:345 - Starting AAIndex feature processing: 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:362 - Output directory created/verified: 3_Graph_Data/TS/aaindex_features
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:379 - Dataset size: 9297 sequences
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:380 - Output directory: 3_Graph_Data/TS/aaindex_features
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:391 - Found 9297 existing AAIndex feature files
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.aaindex:process_dataset:394 - All AAIndex feature files exist, skipping processing
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:automated_pipeline:798 - Feature extraction results: {'esmfold_processed': 9297, 'aaindex_success': 9297, 'aaindex_failed': 0}
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:automated_pipeline:801 - Step 3: Building graphs from CSV
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:automated_pipeline:802 - ============================================================
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:build_graphs_from_csv:594 - Starting graph construction: 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:204 - Loaded 9297 sequences from 1_Data/Processed_data_set/Final_merged_data_set/TS.csv
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:208 - Sequence length range: 5-50, average: 29.6
# 2025-06-27 15:46:57 | INFO     | Feature_extraction.graph_builder:load_and_validate_csv:212 - Label distribution: {0: 7894, 1: 1403}
# Building graphs-strict mode (AAIdx, 4.0Å): 100%|██████████| 9297/9297 [00:51<00:00, 181.69graph/s, success=9297/9297, time=0.011s, ETA=0s, status=✓]
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:build_graphs_from_csv:645 - Graph construction complete: 9297/9297 successful
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:build_graphs_from_csv:646 - Total time: 51s
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:656 - Detailed statistics:
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:657 -   Successful graphs: 9297
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:658 -   Failed sequences: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:659 -   Length mismatch errors: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:660 -   Missing PDB: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:661 -   Missing ESMC: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:662 -   Missing AAIndex: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:663 -   Processing errors: 0
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:_report_statistics:666 -   Feature dimensions: {'AAIdx(553)': 553}
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:automated_pipeline:811 - Graph building complete: 9297 graphs created
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:automated_pipeline:815 - Step 4: Validating output graphs
# 2025-06-27 15:47:48 | INFO     | Feature_extraction.graph_builder:automated_pipeline:816 - ============================================================
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:720 - Graph validation results:
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:721 -   Total graphs: 9297
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:722 -   Node count range: 5-50
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:723 -   Edge count range: 2-104
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:724 -   Feature dimensions: [553]
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:725 -   Label distribution: {0: 7894, 1: 1403}
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:validate_graphs:732 -   ✅ No anomalies detected
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:automated_pipeline:819 - Graph validation results: {'total_graphs': 9297, 'node_count_range': {'min': 5, 'max': 50, 'mean': np.float64(29.625578143487147)}, 'edge_count_range': {'min': 2, 'max': 104, 'mean': np.float64(56.22781542433043)}, 'feature_dimension': {'unique_dims': [553], 'most_common': 553}, 'label_distribution': {0: 7894, 1: 1403}, 'anomalies': []}
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:automated_pipeline:825 - Step 5: Saving dataset
# 2025-06-27 15:47:49 | INFO     | Feature_extraction.graph_builder:automated_pipeline:826 - ============================================================
# 2025-06-27 15:47:54 | INFO     | Feature_extraction.graph_builder:automated_pipeline:844 - Dataset saved: 3_Graph_Data/TS/TS_AAIndex_4.0A.pkl
# 2025-06-27 15:47:54 | INFO     | Feature_extraction.graph_builder:automated_pipeline:847 - Pipeline complete: 9297 graphs processed, total time 58s
# 📊 Total sequences: 9297, successful: 9297, success rate: 100.0%
# 🎯 Graph label distribution: {0: 7894, 1: 1403}
# 💾 Saved to: 3_Graph_Data/TS/TS_AAIndex_4.0A.pkl
# ✅ Processing completed!
